# %%
lista = []

# %%
lista_numerica = [1, 2, 3]
print(lista_numerica)
# Out:
# [1, 2, 3]

# %%
lista_mista = [13, 'lista', [4,7,8], True, lista_numerica]

# %%
#saber o cumprimento da lista|Quantos tipos de dados ela possui 
len(lista_mista)
# Out:
# 5

# %%
#essa estrutura de dados não podem ser editados, são fixos
tupla = (2, 3, 4)
#tupla.append(5)

# %%
# É uma sequência de itens no modelo de chave e valor
dicionario = {
    
    'gata': 'Felino domesticado',
    'legenda': 1,
    'cidade': 'Santa Catarina',
    'residente': True

              }

dicionario['gata']
# Out:
# 'Felino domesticado'
