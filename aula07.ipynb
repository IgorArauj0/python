# %%
#Funções no Python

def multiplicarPorCinco(numero):
    return numero * 5
multiplicarPorCinco(2)
# Out:
# 10

# %%
def somaNumeros(numero1, numero2):
    return numero1 + numero2
somaNumeros(2 + 2)

# %%
#Criar uma aula usando Funções com o pop habilitado.
# Out:
# [200, 600, 600, 400]
