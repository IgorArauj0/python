# %%
#Operadores Aritimético|Relacional|Lógico|Associação
1 + 1
3 * 2
5 - 3
10 / 3


x = 13
y = 3

print(x - y)
# Out:
# 10

# %%
#Operadores relacionais
9 > 2  #"Nove é maior que 2 ? "
9 >= 15 #"Nove é maior ou igual a 15 ?"

x <= y

58 == 2
65 != 43
# Out:
# False

# %%
#operadores lógicos, ele retornará se ambas forem verdadeiras
#Lembre-se de rodar linha por linha
3 == 3 and 2 == 2
5 == 1 or 6 == 6
# Out:
# False

# %%
#Operadores de associação
10 in [2, 3, 4, 5, 6, 20]

10 not in [2, 3, 4, 5, 6, 20] #verifica se o 10 NÃO está contido nessa lista
# Out:
# True
